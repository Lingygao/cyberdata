# %% [markdown]
# # Task 3.1: Discretize sensor data (and visualize)

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
from helper import *

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv("../data/training1_no_incidents.csv")
df['DATETIME'] = pd.to_datetime(df['DATETIME'])
df.set_index('DATETIME', inplace=True)

# %% [markdown]
# ### Discretize data

# %%
df_dis = discretize(df, n_sax_symbols=4, hours_in_segment=3, inverse_transform=True)

# %% [markdown]
# ### Visualize

# %%
time_start = "2014-10-12"
time_end   = "2014-10-20"

# Get time slice
og_slice = get_time_slice(df, time_start, time_end)
dc_slice = get_time_slice(df_dis, time_start, time_end)

# %%
feature    = 'F_PU1'

# Visualize discretized series
plot_discretized_series(og_slice[feature], dc_slice[feature], save="output/discretization.pdf")
