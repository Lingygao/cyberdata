# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from helper import *

# %% [markdown]
# # 1. Familiarization Task

# %%
# Load data
df = pd.read_csv("../data/training1_no_incidents.csv")
df['DATETIME'] = pd.to_datetime(df['DATETIME'])
df.set_index('DATETIME', inplace=True)

# %%
df_slice = get_time_slice(df, "2014-07-12", "2014-07-16")
features = ["S_PU8","S_PU4", "F_PU8", "P_J302", "P_J306"]

# Plot slice
plot_data(df_slice, features, figsize=(12,4), save="demo2.png")
